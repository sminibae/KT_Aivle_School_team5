# %%
# imports
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from contextlib import redirect_stdout


import os
import h5py
import json
import gc
import io
import joblib

from sklearn.calibration import LabelEncoder

import matplotlib.pyplot as plt

from PIL import Image

# %%
test_img_path = '/home/all/imgs/Convertibles/ACMEASEFauxLeatherFutonSofaBedwithAdjustableBackrestsTuftedSleeperCouchwithConvertibleArmrestExtendableLoveseatSofawithPillowsforLivingRoomBedroomBrown.jpg'

test_img = Image.open(test_img_path)
# test_img

# %%
model = joblib.load('Conv2D_traditional/svm_model.joblib')
    
# Load the LabelEncoder
le = joblib.load('Conv2D_Deformable/label_encoder.joblib')

# %%
model
# Out:
# RandomForestClassifier()

# %%
from torchvision import transforms
import numpy as np

def process_image(image_path):
    try:
        # Open the image file
        with Image.open(image_path) as img:
            # Resize and convert to RGB
            img = img.resize((64, 64)).convert('RGB')
            # Convert to numpy array and normalize
            img_array = np.asarray(img) / 255.0
            # # Transpose the array to have channels first
            # img_array = img_array.transpose((2, 0, 1))
            return img_array.reshape(1,-1)
    except IOError:
        print(f"Error in processing image: {image_path}")
        return None

# %%
processed_test_img = process_image(test_img_path)
processed_test_img
# Out:
# array([[0.79215686, 0.79607843, 0.77647059, ..., 1.        , 1.        ,
#         1.        ]])

# %%
pred_test_img = model.predict(processed_test_img)
pred_test_img
# Out:
# array([4])

# %%
style = le.inverse_transform(pred_test_img)[0]
style
# Out:
# 'Modern'

# %%
# input img, output Style string
def Style_Classificator(img):
