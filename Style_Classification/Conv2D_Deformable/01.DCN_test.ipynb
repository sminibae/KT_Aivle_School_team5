# %%
import torch

# %%
torch.rand(3,4,10,10)
# Out:
# tensor([[[[0.0252, 0.4968, 0.6951,  ..., 0.0728, 0.4001, 0.3624],
#           [0.1025, 0.5719, 0.0239,  ..., 0.4679, 0.2256, 0.2858],
#           [0.0015, 0.9577, 0.2601,  ..., 0.9029, 0.1032, 0.0066],
#           ...,
#           [0.5879, 0.5771, 0.2901,  ..., 0.6470, 0.6934, 0.6931],
#           [0.0265, 0.9559, 0.9712,  ..., 0.8563, 0.2361, 0.8130],
#           [0.5551, 0.9851, 0.4290,  ..., 0.1671, 0.9015, 0.4694]],
#
#          [[0.5386, 0.6023, 0.6019,  ..., 0.3950, 0.1491, 0.8660],
#           [0.4533, 0.8604, 0.4348,  ..., 0.2780, 0.2674, 0.3310],
#           [0.3681, 0.0915, 0.3077,  ..., 0.8023, 0.6604, 0.7109],
#           ...,
#           [0.7034, 0.8298, 0.2006,  ..., 0.6538, 0.9248, 0.2103],
#           [0.5851, 0.4894, 0.5068,  ..., 0.3479, 0.5848, 0.3579],
#           [0.0965, 0.0987, 0.1304,  ..., 0.3003, 0.3764, 0.0463]],
#
#          [[0.8102, 0.8734, 0.5149,  ..., 0.7565, 0.1566, 0.5989],
#           [0.9779, 0.0527, 0.0822,  ..., 0.8901, 0.8126, 0.5953],
# ...
