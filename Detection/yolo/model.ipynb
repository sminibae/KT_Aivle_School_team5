# %% [markdown]
# ## 로보 플로우 데이터셋

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="TBDNbDNNjBRxOoBGiu48")
project = rf.workspace("mokhamed-nagy-u69zl").project("furniture-detection-qiufc")
dataset = project.version(20).download("yolov8")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from roboflow import Roboflow
#       3 rf = Roboflow(api_key="TBDNbDNNjBRxOoBGiu48")
#       4 project = rf.workspace("mokhamed-nagy-u69zl").project("furniture-detection-qiufc")
#
# ModuleNotFoundError: No module named 'roboflow'

# %% [markdown]
# ## 파일 관련 (이동, 갯수 계산, 사이즈 변환)

# %%
#전체 폴더 이동
# import os
# import shutil

# source_folder = '/content/furniture-detection-20'  # 이동시킬 원본 폴더
# destination_folder = '/content/drive/MyDrive/Colab Notebooks/BigP/dataset'  # 파일을 이동할 대상 폴더

# # 대상 폴더가 없으면 생성
# if not os.path.exists(destination_folder):
#     os.makedirs(destination_folder)

# # 원본 폴더의 모든 내용(파일 및 하위 폴더)을 대상 폴더로 이동
# for item in os.listdir(source_folder):
#     source_path = os.path.join(source_folder, item)
#     destination_path = os.path.join(destination_folder, item)

#     # 이동
#     shutil.move(source_path, destination_path)

# %%
#파일 이동
import os
import shutil

source_folder = '/content/runs/detect/train/weights'
destination_folder = '/content/drive/MyDrive/Colab Notebooks/BigP/weights/x_e100'

# 대상 폴더가 없으면 생성
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

for filename in os.listdir(source_folder):
    source_path = os.path.join(source_folder, filename)
    destination_path = os.path.join(destination_folder, filename)
    # 파일 이동
    shutil.move(source_path, destination_path)

# %%
#파일 수 계산
import os
def count_files(directory):
    return sum([len(files) for r, d, files in os.walk(directory)])

aa = '/content/drive/MyDrive/Colab Notebooks/BigP/dataset/valid'  # 폴더 경로 지정
folder_path = f'{aa}/images'  # 폴더 경로 지정
folder_path2 = f'{aa}/labels'  # 폴더 경로 지정
print(f"images 파일 수: {count_files(folder_path)}")
print(f"labels 파일 수: {count_files(folder_path2)}")
# Out:
# images 파일 수: 891
# labels 파일 수: 891

# %%
# 이미지 크기 조절
from ultralytics import YOLO
from PIL import Image
import os, torch

folder_path = '/content/'
for filename in os.listdir(folder_path):
    if filename.endswith('.png'):
        img_path = os.path.join(folder_path, filename)
        with Image.open(img_path) as img:
            # 이미지 크기 조절
            img_resized = img.resize((640, 640))

            # 변경된 이미지 저장
            img_resized.save(img_path)

# %% [markdown]
# ## YOLOv8

# %% [markdown]
# ### large Model

# %%
#라지 모델 불러오기
from ultralytics import YOLO
model_l = YOLO('yolov8l.yaml').load('C:\\Users\\user\\Desktop\\Detector\\best.pt')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  3   4461568  ultralytics.nn.modules.block.C2f             [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  16                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   4592640  ultralytics.nn.modules.block.C2f             [768, 512, 3]
#  19                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  22        [15, 18, 21]  1   5644480  ultralytics.nn.modules.head.Detect           [80, [256, 512, 512]]
# YOLOv8l summary: 365 layers, 43691520 parameters, 43691504 gradients, 165.7 GFLOPs
#
# Transferred 589/595 items from pretrained weights

# %%
#라지 모델 학습 / patience - 몇번까지 성능향상 없으면 조기중단
results_l = model_l.train(data='/content/drive/MyDrive/Colab Notebooks/BigP/dataset/data.yaml', epochs=1, imgsz=416)

# %%
fn = ['1','2','3','4','5','6']
for n in fn:
    model_l.predict(f"C:\\Users\\user\\Desktop\\Detector\\모던{n}.png", save=True, imgsz=640, conf=0.1)
# Out:
# image 1/1 C:\Users\user\Desktop\Detector\모던1.png: 576x640 (no detections), 768.1ms
# Speed: 14.1ms preprocess, 768.1ms inference, 11.2ms postprocess per image at shape (1, 3, 576, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\user\Desktop\Detector\모던2.png: 416x640 (no detections), 465.8ms
# Speed: 2.0ms preprocess, 465.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\user\Desktop\Detector\모던3.png: 384x640 (no detections), 414.5ms
# Speed: 1.5ms preprocess, 414.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\user\Desktop\Detector\모던4.png: 416x640 (no detections), 520.0ms
# Speed: 1.5ms preprocess, 520.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\user\Desktop\Detector\모던5.png: 512x640 (no detections), 537.1ms
# Speed: 2.0ms preprocess, 537.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\user\Desktop\Detector\모던6.png: 448x640 (no detections), 518.2ms
# Speed: 2.0ms preprocess, 518.2ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\detect\predict

# %% [markdown]
# ### extreme

# %%
#익스트림 모델 불러오기
from ultralytics import YOLO
model_x = YOLO('yolov8x.yaml').load('/content/drive/MyDrive/Colab Notebooks/BigP/weights/x_e100/best.pt')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8795008  ultralytics.nn.modules.head.Detect           [80, [320, 640, 640]]
# YOLOv8x summary: 365 layers, 68229648 parameters, 68229632 gradients, 258.5 GFLOPs
#
# Transferred 589/595 items from pretrained weights

# %%
#익스트림 학습
results_x = model_x.train(data='/content/drive/MyDrive/Colab Notebooks/BigP/dataset/data.yaml', epochs=50, imgsz=416, patience=10, resume=True)
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# engine/trainer: task=detect, mode=train, model=yolov8x.yaml, data=/content/drive/MyDrive/Colab Notebooks/BigP/dataset/data.yaml, epochs=50, time=None, patience=10, batch=16, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=None, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 37.4MB/s]
# Overriding model.yaml nc=80 with nc=25
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8742043  ultralytics.nn.modules.head.Detect           [25, [320, 640, 640]]
# YOLOv8x summary: 365 layers, 68176683 parameters, 68176667 gradients, 258.3 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 196MB/s]
# WARNING ⚠️ NMS time limit 0.550s exceeded
# AMP: checks passed ✅

# %%
#디렉토리 내 모든 파일 이동
import os
import shutil

source_folder = '/content/runs/detect/train/weights'
destination_folder = '/content/drive/MyDrive/Colab Notebooks/BigP/weights/x_e100'

# 대상 폴더가 없으면 생성
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

for filename in os.listdir(source_folder):
    source_path = os.path.join(source_folder, filename)
    destination_path = os.path.join(destination_folder, filename)
    # 파일 이동
    shutil.move(source_path, destination_path)

# %% [markdown]
# ## 로보 플로우 모델

# %%
#로보 플로우 모델
from roboflow import Roboflow
rf = Roboflow(api_key="TBDNbDNNjBRxOoBGiu48")
project = rf.workspace().project("furniture-detection-qiufc")
model = project.version(20).model
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
#로보 플로우 예측
import os

imgJson = []
folder_path = 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data'
save_predict = 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\yolo\\predict_img'
file_names = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

for fn in file_names:
    model.predict(f"{folder_path}\\{fn}", confidence=50, overlap=20).save(f'{save_predict}\\pred_{fn}')
    imgJson.append(model.predict(f"{folder_path}\\{fn}", confidence=50, overlap=20).json())

# %% [markdown]
# ## 이미지 크롭

# %% [markdown]
# #### 박스만 남기기

# %%
import cv2

save_crop = f'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\yolo\\crop_img'

for n in range(len(file_names)):
    full_path = f"{folder_path}\\{file_names[n]}"    
    img = cv2.imread(full_path)
        
    boxes = []
    NN = len(imgJson[n]['predictions'])
    for N in range(NN): # N번째 박스
        print(imgJson[n]['predictions'][N])
        xh = int(imgJson[n]['predictions'][N]['width']/2)
        yh = int(imgJson[n]['predictions'][N]['height']/2)
        x1 = imgJson[n]['predictions'][N]['x'] - xh
        y1 = imgJson[n]['predictions'][N]['y'] - yh
        x2 = imgJson[n]['predictions'][N]['x'] + xh
        y2 = imgJson[n]['predictions'][N]['y'] + yh
        boxes.append([x1, y1, x2, y2])
    
    for i, box in enumerate(boxes):
        x1, y1, x2, y2 = box
        print(box, x1, y1, x2, y2)
        # 바운딩 박스 영역 잘라내기
        cropped_img = img[y1:y2, x1:x2]
        cv2.imwrite(f'{save_crop}\\crop_{file_names[n]}_{i}.jpg', cropped_img)
        print(f"Saved cropped image")
# Out:
# {'x': 789, 'y': 950, 'width': 1420, 'height': 955, 'confidence': 0.6043277382850647, 'class': 'Table', 'class_id': 20, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AAIRLLENComputerDeskInchModernSimpleSturdyNotebookWritingDeskStudyOfficeTableforHomeOfficeDinningTableWorkstationDeskEscritoriodeOrdenador.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [79, 473, 1499, 1427] 79 473 1499 1427
# Saved cropped image
# {'x': 919, 'y': 1191, 'width': 1153, 'height': 616, 'confidence': 0.6365021467208862, 'class': 'Wooden floor', 'class_id': 24, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AAIRLLENSleekandSturdyInchComputerDeskModernDesignforHomeOfficePerfectforWorkandStudyMultiPurposeTableforWritingDiningandWorkstation.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [343, 883, 1495, 1499] 343 883 1495 1499
# Saved cropped image
# {'x': 953, 'y': 1146, 'width': 1063, 'height': 692, 'confidence': 0.6950677633285522, 'class': 'Wooden floor', 'class_id': 24, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AAIRLLENSleekandSturdyInchComputerDeskPerfectforWorkandStudyMultiPurposeTableforWritingDiningandWorkstation.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 196, 'y': 1310, 'width': 393, 'height': 371, 'confidence': 0.672271192073822, 'class': 'Wooden floor', 'class_id': 24, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AAIRLLENSleekandSturdyInchComputerDeskPerfectforWorkandStudyMultiPurposeTableforWritingDiningandWorkstation.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [422, 800, 1484, 1492] 422 800 1484 1492
# Saved cropped image
# [0, 1125, 392, 1495] 0 1125 392 1495
# Saved cropped image
# {'x': 506, 'y': 739, 'width': 915, 'height': 1478, 'confidence': 0.5582656264305115, 'class': 'Table', 'class_id': 20, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeCedroTwinOverTwinBunkBedwithWoodLadderinWeatheredWhite.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [49, 0, 963, 1478] 49 0 963 1478
# Saved cropped image
# {'x': 674, 'y': 653, 'width': 1348, 'height': 1307, 'confidence': 0.6942722201347351, 'class': 'Table', 'class_id': 20, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\ACMEFURNITUREAcmeColeenDeskWhiteBrass.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 0, 1348, 1306] 0 0 1348 1306
# Saved cropped image
# {'x': 668, 'y': 762, 'width': 1324, 'height': 1474, 'confidence': 0.7100116610527039, 'class': 'Bed', 'class_id': 0, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeFurnitureDarleneFarmhouseWoodTwinOverTwinBunkBedinRusticGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [6, 25, 1330, 1499] 6 25 1330 1499
# Saved cropped image
# {'x': 1375, 'y': 564, 'width': 248, 'height': 1075, 'confidence': 0.5573626756668091, 'class': 'Wall Panel', 'class_id': 22, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeFurnitureDrawersWoodenDresserBlackSilverandGold.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [1251, 27, 1499, 1101] 1251 27 1499 1101
# Saved cropped image
# {'x': 186, 'y': 258, 'width': 372, 'height': 272, 'confidence': 0.7889581918716431, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeFurnitureDresserwithStorageDrawersGreyNightStandPlatinum.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 688, 'y': 259, 'width': 429, 'height': 445, 'confidence': 0.6036480069160461, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeFurnitureDresserwithStorageDrawersGreyNightStandPlatinum.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 122, 372, 394] 0 122 372 394
# Saved cropped image
# [474, 37, 902, 481] 474 37 902 481
# Saved cropped image
# {'x': 516, 'y': 461, 'width': 1033, 'height': 923, 'confidence': 0.7292648553848267, 'class': 'Chair', 'class_id': 4, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeFurnitureKaitlynTwinBedwStorageinPUChampagne.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 0, 1032, 922] 0 0 1032 922
# Saved cropped image
# {'x': 755, 'y': 440, 'width': 1460, 'height': 876, 'confidence': 0.9110970497131348, 'class': 'Bed', 'class_id': 0, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeFurnitureKenneyFullBedinEspresso.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [25, 2, 1485, 878] 25 2 1485 878
# Saved cropped image
# {'x': 610, 'y': 746, 'width': 718, 'height': 1492, 'confidence': 0.9147934913635254, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\ACMEFurnitureLouisPhilippeChestWhiteOneSize.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [251, 0, 969, 1492] 251 0 969 1492
# Saved cropped image
# {'x': 1088, 'y': 395, 'width': 822, 'height': 750, 'confidence': 0.9162728190422058, 'class': 'Bed', 'class_id': 0, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeFurnitureWoodenTwinSizeBedWhite.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 342, 'y': 390, 'width': 656, 'height': 780, 'confidence': 0.5719770193099976, 'class': 'Bed', 'class_id': 0, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeFurnitureWoodenTwinSizeBedWhite.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [677, 20, 1499, 770] 677 20 1499 770
# Saved cropped image
# [14, 0, 670, 780] 14 0 670 780
# Saved cropped image
# {'x': 731, 'y': 526, 'width': 1463, 'height': 1043, 'confidence': 0.6073822975158691, 'class': 'Wall Panel', 'class_id': 22, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeHaidenDrawersWoodenDresserwithSilverAccentTriminWeatheredBlack.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 5, 1462, 1047] 0 5 1462 1047
# Saved cropped image
# {'x': 489, 'y': 509, 'width': 906, 'height': 562, 'confidence': 0.826033890247345, 'class': 'Sideboard', 'class_id': 17, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeHestiaDrawerWoodenDresserinWalnutFinish.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [36, 228, 942, 790] 36 228 942 790
# Saved cropped image
# {'x': 346, 'y': 355, 'width': 507, 'height': 710, 'confidence': 0.6879501342773438, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeIrelandDrawerChestinGrayOak.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [93, 0, 599, 710] 93 0 599 710
# Saved cropped image
# {'x': 565, 'y': 746, 'width': 789, 'height': 1492, 'confidence': 0.8888134956359863, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeIrelandDrawerWoodChestinWhite.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [171, 0, 959, 1492] 171 0 959 1492
# Saved cropped image
# {'x': 705, 'y': 462, 'width': 794, 'height': 925, 'confidence': 0.6756367683410645, 'class': 'Lamp', 'class_id': 14, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeJurgenWoodenRectangleTopWritingDeskinOakandBlack.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [308, 0, 1102, 924] 308 0 1102 924
# Saved cropped image
# {'x': 480, 'y': 177, 'width': 914, 'height': 345, 'confidence': 0.6655856966972351, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeJusticeFabricFullDaybedandTwinTrundleinSmokeGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [23, 5, 937, 349] 23 5 937 349
# Saved cropped image
# {'x': 562, 'y': 326, 'width': 1124, 'height': 653, 'confidence': 0.5794830918312073, 'class': 'Bed', 'class_id': 0, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeJuvanthEasternKingWoodenBedwithStorageinOakandBlack.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 0, 1124, 652] 0 0 1124 652
# Saved cropped image
# {'x': 538, 'y': 774, 'width': 1051, 'height': 1399, 'confidence': 0.7703747749328613, 'class': 'Sideboard', 'class_id': 17, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeKaitlynDrawerWoodenChestinChampagneWhite.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 538, 'y': 774, 'width': 1051, 'height': 1406, 'confidence': 0.742840588092804, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeKaitlynDrawerWoodenChestinChampagneWhite.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [13, 75, 1063, 1473] 13 75 1063 1473
# Saved cropped image
# [13, 71, 1063, 1477] 13 71 1063 1477
# Saved cropped image
# {'x': 743, 'y': 471, 'width': 1450, 'height': 928, 'confidence': 0.8168206214904785, 'class': 'Closet', 'class_id': 5, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeKaitlynRectangularWoodDrawerDresserwithinChampagneWhite.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 771, 'y': 467, 'width': 1387, 'height': 912, 'confidence': 0.567927360534668, 'class': 'Sideboard', 'class_id': 17, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeKaitlynRectangularWoodDrawerDresserwithinChampagneWhite.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [18, 7, 1468, 935] 18 7 1468 935
# Saved cropped image
# [78, 11, 1464, 923] 78 11 1464 923
# Saved cropped image
# {'x': 1346, 'y': 221, 'width': 306, 'height': 436, 'confidence': 0.7129511833190918, 'class': 'Window', 'class_id': 23, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeLaraTwinWoodenLoftBedwithGuardRailandReversibleLadderinGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 530, 'y': 284, 'width': 223, 'height': 266, 'confidence': 0.5837387442588806, 'class': 'Frame', 'class_id': 10, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeLaraTwinWoodenLoftBedwithGuardRailandReversibleLadderinGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 748, 'y': 950, 'width': 1467, 'height': 998, 'confidence': 0.5714917182922363, 'class': 'Transparent Closet', 'class_id': 21, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeLaraTwinWoodenLoftBedwithGuardRailandReversibleLadderinGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [1193, 3, 1499, 439] 1193 3 1499 439
# Saved cropped image
# [419, 151, 641, 417] 419 151 641 417
# Saved cropped image
# [15, 451, 1481, 1449] 15 451 1481 1449
# Saved cropped image
# {'x': 314, 'y': 431, 'width': 573, 'height': 850, 'confidence': 0.6869702339172363, 'class': 'Sideboard', 'class_id': 17, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeLouisPhilippeChestinBlack.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [28, 6, 600, 856] 28 6 600 856
# Saved cropped image
# {'x': 326, 'y': 455, 'width': 622, 'height': 898, 'confidence': 0.8624463677406311, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeLouisPhilippeChestinDarkGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [15, 6, 637, 904] 15 6 637 904
# Saved cropped image
# {'x': 330, 'y': 554, 'width': 536, 'height': 1108, 'confidence': 0.8534326553344727, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeLouisPhilippeChestinPlatinum.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [62, 0, 598, 1108] 62 0 598 1108
# Saved cropped image
# {'x': 453, 'y': 313, 'width': 903, 'height': 582, 'confidence': 0.8755999207496643, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeLouisPhilippeDresserinDarkGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [2, 22, 904, 604] 2 22 904 604
# Saved cropped image
# {'x': 753, 'y': 509, 'width': 1492, 'height': 970, 'confidence': 0.9178084135055542, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeLouisPhilippeDresserinWhite.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [7, 24, 1499, 994] 7 24 1499 994
# Saved cropped image
# {'x': 317, 'y': 318, 'width': 144, 'height': 135, 'confidence': 0.6836252212524414, 'class': 'Frame', 'class_id': 10, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeLouisPhilippeFullBedinBlack.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 479, 'y': 329, 'width': 129, 'height': 132, 'confidence': 0.6279937624931335, 'class': 'Frame', 'class_id': 10, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeLouisPhilippeFullBedinBlack.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 571, 'y': 729, 'width': 753, 'height': 484, 'confidence': 0.5471971035003662, 'class': 'Bed', 'class_id': 0, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeLouisPhilippeFullBedinBlack.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 146, 'y': 752, 'width': 191, 'height': 194, 'confidence': 0.537917971611023, 'class': 'Nightstand', 'class_id': 15, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeLouisPhilippeFullBedinBlack.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [245, 251, 389, 385] 245 251 389 385
# Saved cropped image
# [415, 263, 543, 395] 415 263 543 395
# Saved cropped image
# [195, 487, 947, 971] 195 487 947 971
# Saved cropped image
# [51, 655, 241, 849] 51 655 241 849
# Saved cropped image
# {'x': 757, 'y': 566, 'width': 1478, 'height': 1096, 'confidence': 0.9059807062149048, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeLouisPhilippeRectangularWoodDrawerDresserinCherry.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 771, 'y': 562, 'width': 1449, 'height': 1098, 'confidence': 0.7154186964035034, 'class': 'Sideboard', 'class_id': 17, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeLouisPhilippeRectangularWoodDrawerDresserinCherry.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [18, 18, 1496, 1114] 18 18 1496 1114
# Saved cropped image
# [47, 13, 1495, 1111] 47 13 1495 1111
# Saved cropped image
# {'x': 766, 'y': 497, 'width': 1294, 'height': 989, 'confidence': 0.8481100797653198, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeMadisonDrawerDresserinEspresso.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [119, 3, 1413, 991] 119 3 1413 991
# Saved cropped image
# {'x': 351, 'y': 592, 'width': 290, 'height': 615, 'confidence': 0.8033177852630615, 'class': 'Nightstand', 'class_id': 15, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeMaverickDrawerWoodenLingerieChestinWhitePlatinum.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [206, 285, 496, 899] 206 285 496 899
# Saved cropped image
# {'x': 363, 'y': 257, 'width': 727, 'height': 515, 'confidence': 0.864476203918457, 'class': 'Sideboard', 'class_id': 17, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeMiquellDresserinNatural.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 361, 'y': 249, 'width': 723, 'height': 498, 'confidence': 0.598660945892334, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeMiquellDresserinNatural.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 0, 726, 514] 0 0 726 514
# Saved cropped image
# [0, 0, 722, 498] 0 0 722 498
# Saved cropped image
# {'x': 632, 'y': 458, 'width': 1265, 'height': 916, 'confidence': 0.6815024614334106, 'class': 'Bed', 'class_id': 0, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeMiquellWoodRectangularHeadboardQueenPanelBedinNatural.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 0, 1264, 916] 0 0 1264 916
# Saved cropped image
# {'x': 369, 'y': 454, 'width': 654, 'height': 908, 'confidence': 0.6644786596298218, 'class': 'Sideboard', 'class_id': 17, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeNorthvilleDrawerWoodenChestinAntiqueSilver.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [42, 0, 696, 908] 42 0 696 908
# Saved cropped image
# {'x': 651, 'y': 894, 'width': 504, 'height': 1197, 'confidence': 0.599071741104126, 'class': 'Nightstand', 'class_id': 15, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeNysaCabinetwithDrawersinMirrored.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 650, 'y': 915, 'width': 501, 'height': 1146, 'confidence': 0.567233681678772, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeNysaCabinetwithDrawersinMirrored.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [399, 296, 903, 1492] 399 296 903 1492
# Saved cropped image
# [400, 342, 900, 1488] 400 342 900 1488
# Saved cropped image
# {'x': 702, 'y': 420, 'width': 1404, 'height': 840, 'confidence': 0.7023072838783264, 'class': 'Bed', 'class_id': 0, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AcmeSanMarinoTwinWoodenPanelBedinWhite.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 0, 1404, 840] 0 0 1404 840
# Saved cropped image
# {'x': 525, 'y': 604, 'width': 1050, 'height': 1104, 'confidence': 0.8056046962738037, 'class': 'Table', 'class_id': 20, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\AdjustableHeightDeskStandingDeskLaptopTableAdjustableDeskForKidsChildrensWorkstationSitToStandDeskLiftDeskStudyTableHomeOfficeTableKidsStudyDeskColorWhiteSize.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 52, 1050, 1156] 0 52 1050 1156
# Saved cropped image
# {'x': 699, 'y': 824, 'width': 1391, 'height': 1227, 'confidence': 0.7665482759475708, 'class': 'Table', 'class_id': 20, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\ADOFFURElectricStandingDeskxInchHeightAdjustableSitStandUpDeskErgonomicMotorizedComputerDeskwithHeadphoneHookMemoryPanelforHomeOfficeBlackRusticBrownSpliceTop.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [4, 211, 1394, 1437] 4 211 1394 1437
# Saved cropped image
# {'x': 728, 'y': 1000, 'width': 1456, 'height': 998, 'confidence': 0.5577923059463501, 'class': 'Table', 'class_id': 20, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\ADOFFURStandingDeskwithDrawerElectricHeightAdjustableDeskwithxInchTemperedGlassTopSitStandHomeOfficeDeskwithWirelessChargingTouchControlUSBPortsWhite.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 501, 1456, 1499] 0 501 1456 1499
# Saved cropped image
# {'x': 766, 'y': 939, 'width': 919, 'height': 876, 'confidence': 0.747713565826416, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\ADORNEVEWritingDeskwithUSBPortHomeOfficeDeskwithDrawersandHutchStudyTableComputerDeskforStudentAdultsComputerWorkStationwithStorageShelfDrawersWhite.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [307, 501, 1225, 1377] 307 501 1225 1377
# Saved cropped image
# {'x': 719, 'y': 289, 'width': 1438, 'height': 578, 'confidence': 0.8438215255737305, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\CasaAndreaMilanoModernVelvetFabricSectionalSofaLShapeCouchwithExtraWideChaiseLounge.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 0, 1438, 578] 0 0 1438 578
# Saved cropped image
# {'x': 726, 'y': 892, 'width': 1453, 'height': 868, 'confidence': 0.8170931339263916, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\CHITAOversizedModularSectionalFabricSofaSetExtraLargeLShapedCouchwithReversibleChaiseModularSectionalCouchinchWidthSeatModularSofawithStorageOttamanLinen.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 1393, 'y': 407, 'width': 212, 'height': 814, 'confidence': 0.7027231454849243, 'class': 'Window', 'class_id': 23, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\CHITAOversizedModularSectionalFabricSofaSetExtraLargeLShapedCouchwithReversibleChaiseModularSectionalCouchinchWidthSeatModularSofawithStorageOttamanLinen.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 167, 'y': 326, 'width': 292, 'height': 371, 'confidence': 0.6054579019546509, 'class': 'Frame', 'class_id': 10, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\CHITAOversizedModularSectionalFabricSofaSetExtraLargeLShapedCouchwithReversibleChaiseModularSectionalCouchinchWidthSeatModularSofawithStorageOttamanLinen.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 555, 'y': 292, 'width': 274, 'height': 331, 'confidence': 0.5552124381065369, 'class': 'Frame', 'class_id': 10, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\CHITAOversizedModularSectionalFabricSofaSetExtraLargeLShapedCouchwithReversibleChaiseModularSectionalCouchinchWidthSeatModularSofawithStorageOttamanLinen.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 458, 1452, 1326] 0 458 1452 1326
# Saved cropped image
# [1287, 0, 1499, 814] 1287 0 1499 814
# Saved cropped image
# [21, 141, 313, 511] 21 141 313 511
# Saved cropped image
# [418, 127, 692, 457] 418 127 692 457
# Saved cropped image
# {'x': 755, 'y': 562, 'width': 1489, 'height': 1038, 'confidence': 0.9107627868652344, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\CouchDefenderKeepPetsOffofYourFurnitureBlack.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [11, 43, 1499, 1081] 11 43 1499 1081
# Saved cropped image
# {'x': 1209, 'y': 227, 'width': 227, 'height': 454, 'confidence': 0.7310788631439209, 'class': 'Window', 'class_id': 23, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\DevionFurnitureContemporaryReversibleSectionalSleeperSectionalSofawithStorageChaiseinDarkGrayFabric.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 614, 'y': 566, 'width': 948, 'height': 577, 'confidence': 0.5816178321838379, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\DevionFurnitureContemporaryReversibleSectionalSleeperSectionalSofawithStorageChaiseinDarkGrayFabric.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [1096, 0, 1322, 454] 1096 0 1322 454
# Saved cropped image
# [140, 278, 1088, 854] 140 278 1088 854
# Saved cropped image
# {'x': 377, 'y': 433, 'width': 755, 'height': 866, 'confidence': 0.9206037521362305, 'class': 'Chair', 'class_id': 4, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\DLOETTMinimalistSingleLeisureChairNordicLightChairLazySnailSofaRecliner.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 0, 754, 866] 0 0 754 866
# Saved cropped image
# {'x': 659, 'y': 883, 'width': 1240, 'height': 750, 'confidence': 0.5109547972679138, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\FlamakerConvertibleSectionalSofaCouchModernFabricUShapedLivingRoomFurnitureSetSeatSectionalSleeperSofawithDoubleChaiseMemoryFoamGrey.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [39, 508, 1279, 1258] 39 508 1279 1258
# Saved cropped image
# {'x': 755, 'y': 823, 'width': 1424, 'height': 897, 'confidence': 0.5258664488792419, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\FlamakerSectionalCouchSofaCouchforLivingRoomLShapedCouchwithReversibleChaiseFabricSmallCouchesforApartmentSmallSpacesDarkGrey.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [43, 375, 1467, 1271] 43 375 1467 1271
# Saved cropped image
# {'x': 662, 'y': 748, 'width': 1324, 'height': 1496, 'confidence': 0.9251024723052979, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\HomePopUpholsteredClassicSwoopArmAccentChairHomeDcorLinenlookSoftCream.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 662, 'y': 735, 'width': 1324, 'height': 1471, 'confidence': 0.9111678600311279, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\HomePopUpholsteredClassicSwoopArmAccentChairHomeDcorLinenlookSoftCream.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 662, 'y': 750, 'width': 1324, 'height': 1500, 'confidence': 0.840778648853302, 'class': 'Chair', 'class_id': 4, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\HomePopUpholsteredClassicSwoopArmAccentChairHomeDcorLinenlookSoftCream.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 0, 1324, 1496] 0 0 1324 1496
# Saved cropped image
# [0, 0, 1324, 1470] 0 0 1324 1470
# Saved cropped image
# [0, 0, 1324, 1500] 0 0 1324 1500
# Saved cropped image
# {'x': 865, 'y': 903, 'width': 1269, 'height': 652, 'confidence': 0.642451286315918, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\HONBAYConvertibleSectionalSofaLShapedCouchwithReversibleChaiseforSmallSpaceDarkGrey.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [231, 577, 1499, 1229] 231 577 1499 1229
# Saved cropped image
# {'x': 750, 'y': 852, 'width': 1500, 'height': 1171, 'confidence': 0.773105263710022, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\HONBAYModularSofaSleeperSectionalConvertibleModularCouchwithStorageSeatsModularSofaSleeperSectionalSofaBedBluishGrey.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 267, 1500, 1437] 0 267 1500 1437
# Saved cropped image
# {'x': 519, 'y': 337, 'width': 1038, 'height': 674, 'confidence': 0.7289977073669434, 'class': 'Table', 'class_id': 20, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\HONBAYSquareOttomanModuleforModularSectionalSofaStorageOttomanFootrestandSeatCubeGrey.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 0, 1038, 674] 0 0 1038 674
# Saved cropped image
# {'x': 856, 'y': 894, 'width': 1272, 'height': 692, 'confidence': 0.5476199984550476, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\HONBAYVelvetConvertibleSectionalSofaLShapedCouchwithReversibleChaiseforSmallApartmentGreen.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [220, 548, 1492, 1240] 220 548 1492 1240
# Saved cropped image
# {'x': 750, 'y': 841, 'width': 1456, 'height': 1316, 'confidence': 0.5802903771400452, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\JUMMICOConvertibleSectionalSofaCouchLShapedCouchwithReversibleChaiseModernLinenFabricCouchesforLivingRoomApartmentandSmallSpaceDarkGrey.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [22, 183, 1478, 1499] 22 183 1478 1499
# Saved cropped image
# {'x': 759, 'y': 980, 'width': 1453, 'height': 750, 'confidence': 0.5254443287849426, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\JUMMICOConvertibleSectionalSofaCouchSeatSofaSetforLivingRoomwithThrowPillowsUShapedModernMinimalistFabricModularSofawithDoubleChaiseMemoryFoamGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [33, 605, 1485, 1355] 33 605 1485 1355
# Saved cropped image
# {'x': 324, 'y': 550, 'width': 649, 'height': 640, 'confidence': 0.6394096612930298, 'class': 'Chair', 'class_id': 4, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\KakaoTalk_20231222_091606817.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 230, 648, 870] 0 230 648 870
# Saved cropped image
# {'x': 1063, 'y': 371, 'width': 213, 'height': 389, 'confidence': 0.728884756565094, 'class': 'Chair', 'class_id': 4, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\KakaoTalk_20231222_091606817_01.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [957, 177, 1169, 565] 957 177 1169 565
# Saved cropped image
# {'x': 759, 'y': 919, 'width': 1453, 'height': 915, 'confidence': 0.590738832950592, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\KingfunFauxLeatherLoveseatSofasforLivingRoomSmallCouchesforSmallSpacesBedroomwithSolidWoodenFrameandPaddedCushionMidCenturyModernDecorLoveSeatsFurnitureBrown.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [33, 462, 1485, 1376] 33 462 1485 1376
# Saved cropped image
# {'x': 527, 'y': 432, 'width': 1054, 'height': 856, 'confidence': 0.9317165613174438, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\LifestyleSolutionsLexingtonArmchairNavyBlue.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 4, 1054, 860] 0 4 1054 860
# Saved cropped image
# {'x': 677, 'y': 393, 'width': 1355, 'height': 786, 'confidence': 0.8753758668899536, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\LilolaHomeLinenReversibleSleeperSectionalSofawithStorageChaiseDarkGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 0, 1354, 786] 0 0 1354 786
# Saved cropped image
# {'x': 750, 'y': 668, 'width': 1435, 'height': 557, 'confidence': 0.6128457188606262, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\LINSYHOMEModularSectionalSofaConvertibleUShapedSofaCouchwithStorageMemoryFoamModularSectionalswithOttomansSeatOversizedSofaCouchwithChaiseforLivingRoomGrey.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 631, 'y': 138, 'width': 692, 'height': 217, 'confidence': 0.5744785666465759, 'class': 'Cabinet', 'class_id': 1, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\LINSYHOMEModularSectionalSofaConvertibleUShapedSofaCouchwithStorageMemoryFoamModularSectionalswithOttomansSeatOversizedSofaCouchwithChaiseforLivingRoomGrey.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [33, 390, 1467, 946] 33 390 1467 946
# Saved cropped image
# [285, 30, 977, 246] 285 30 977 246
# Saved cropped image
# {'x': 1242, 'y': 131, 'width': 248, 'height': 262, 'confidence': 0.698531448841095, 'class': 'Window', 'class_id': 23, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\LivavegeConvertibleSleeperSectionalSofawithPullBedLShapedwStorageChaiseModernLinenFabricCornerSeatersCouchesforLivingRoomApartmentandSmallSpaceDarkGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 849, 'y': 584, 'width': 1200, 'height': 750, 'confidence': 0.5671612620353699, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\LivavegeConvertibleSleeperSectionalSofawithPullBedLShapedwStorageChaiseModernLinenFabricCornerSeatersCouchesforLivingRoomApartmentandSmallSpaceDarkGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [1118, 0, 1366, 262] 1118 0 1366 262
# Saved cropped image
# [249, 209, 1449, 959] 249 209 1449 959
# Saved cropped image
# {'x': 1220, 'y': 145, 'width': 227, 'height': 290, 'confidence': 0.7452041506767273, 'class': 'Window', 'class_id': 23, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\LivavegeConvertibleSleeperSectionalSofawithStorageChaiseandPullOutBedButtonTuftedBackrestLinenUpholsteredReversibleCornerPersonLShapeCouchforSmallLivingRoomApartment.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [1107, 0, 1333, 290] 1107 0 1333 290
# Saved cropped image
# {'x': 592, 'y': 1013, 'width': 1167, 'height': 973, 'confidence': 0.6428372859954834, 'class': 'Sideboard', 'class_id': 17, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\MeliuslyExtraWideLoveseatCushionSupportBoardxDeepLoveseatSupportforSaggingCushionsLoveseatSupportBoardUnderCushionsforSeatCouchSaggySofaLoveSeatSupportInserts.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [9, 527, 1175, 1499] 9 527 1175 1499
# Saved cropped image
# {'x': 716, 'y': 587, 'width': 590, 'height': 435, 'confidence': 0.7578272819519043, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\NALivingRoomFurnitureLinenFabricFauxLeatherwithWoodLegSectionalItems.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 930, 'y': 225, 'width': 177, 'height': 258, 'confidence': 0.7460375428199768, 'class': 'Frame', 'class_id': 10, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\NALivingRoomFurnitureLinenFabricFauxLeatherwithWoodLegSectionalItems.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 242, 'y': 562, 'width': 440, 'height': 352, 'confidence': 0.5697916150093079, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\NALivingRoomFurnitureLinenFabricFauxLeatherwithWoodLegSectionalItems.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 129, 'y': 257, 'width': 238, 'height': 504, 'confidence': 0.5621259212493896, 'class': 'Window', 'class_id': 23, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\NALivingRoomFurnitureLinenFabricFauxLeatherwithWoodLegSectionalItems.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [421, 370, 1011, 804] 421 370 1011 804
# Saved cropped image
# [842, 96, 1018, 354] 842 96 1018 354
# Saved cropped image
# [22, 386, 462, 738] 22 386 462 738
# Saved cropped image
# [10, 5, 248, 509] 10 5 248 509
# Saved cropped image
# {'x': 742, 'y': 993, 'width': 1348, 'height': 710, 'confidence': 0.7457159757614136, 'class': 'Sideboard', 'class_id': 17, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\OpoiarMidCenturyModernBrownLeatherConvertibleSectionalLoveseatSofawithWoodenFrameMemoryFoamCushionsPerfectforSmallSpacesTwin.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 742, 'y': 993, 'width': 1348, 'height': 710, 'confidence': 0.7361014485359192, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\OpoiarMidCenturyModernBrownLeatherConvertibleSectionalLoveseatSofawithWoodenFrameMemoryFoamCushionsPerfectforSmallSpacesTwin.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [68, 638, 1416, 1348] 68 638 1416 1348
# Saved cropped image
# [68, 638, 1416, 1348] 68 638 1416 1348
# Saved cropped image
# {'x': 753, 'y': 610, 'width': 1463, 'height': 1150, 'confidence': 0.9036284685134888, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\PaPaJetInchSleeperSofaBedTuftedPullOutSofaBedwithUSBPortsCupHoldersLShapeSectionalSofaBedwithStorageChaiseDarkGrey.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [22, 35, 1484, 1185] 22 35 1484 1185
# Saved cropped image
# {'x': 534, 'y': 616, 'width': 950, 'height': 558, 'confidence': 0.602705717086792, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\SDGHConvertibleSectionalSofaChenilleLShapedSofaCouchwithReversibleChaiseLoungeFitforLivingRoomApartmentColorESizeAsShown.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [59, 337, 1009, 895] 59 337 1009 895
# Saved cropped image
# {'x': 470, 'y': 190, 'width': 931, 'height': 381, 'confidence': 0.8456635475158691, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\SDGHUShapeSofaSectionalSofaIncludingSingleSeatsChaisesModularSofaLoopYarnFabricLivingRoomSofaColorESizeAsShown.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [5, 0, 935, 380] 5 0 935 380
# Saved cropped image
# {'x': 750, 'y': 394, 'width': 1500, 'height': 789, 'confidence': 0.9478974342346191, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\STHOUYNWSectionalSofaSeatCouchMidCenturyModernSofawithUSBCouchesSofasforLivingRoomApartmentBedroomComfortableSmallCouchesforSmallSpacesDarkGreySeater.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 0, 1500, 788] 0 0 1500 788
# Saved cropped image
# {'x': 750, 'y': 346, 'width': 1500, 'height': 686, 'confidence': 0.94246506690979, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\ThunderStarLShapedSectionalSofaSofawithChaiseSeatSofawithOneFootstoolModernLivingRoomFurnitureSturdyEasytoInstallDarkGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 3, 1500, 689] 0 3 1500 689
# Saved cropped image
# {'x': 1220, 'y': 145, 'width': 227, 'height': 290, 'confidence': 0.7452041506767273, 'class': 'Window', 'class_id': 23, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\TUTBLinenUpholsteredLShapeConvertibleSleeperSectionalSofawithStorageChaiseandPullOutBedforLivingRoomApartmentOfficeDarkGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [1107, 0, 1333, 290] 1107 0 1333 290
# Saved cropped image
# {'x': 829, 'y': 594, 'width': 1341, 'height': 1067, 'confidence': 0.8565124273300171, 'class': 'Bed', 'class_id': 0, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\VanAccSleeperSofainPullOutBedwithStorageChaiseforLivingRoomGreyChenilleCouch.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [159, 61, 1499, 1127] 159 61 1499 1127
# Saved cropped image
# {'x': 1260, 'y': 1137, 'width': 465, 'height': 501, 'confidence': 0.6073022484779358, 'class': 'TV stand', 'class_id': 19, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\VICTONEConvertibleSectionalSofaCouchSeatLShapedSofawithLinenFabricMovableOttomanSmallCouchforSmallApartmentsLivingRoomandOfficeDarkGrey.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [1028, 887, 1492, 1387] 1028 887 1492 1387
# Saved cropped image
# {'x': 750, 'y': 708, 'width': 1500, 'height': 1417, 'confidence': 0.9252053499221802, 'class': 'Chair', 'class_id': 4, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\VINGLIMidCenturyModernAccentChairLightGreyFabricChairsforLivingRoomUpholsteredArmchairwithScoopedArmsforBedroomApartmentStudioOfficeWaitingRoom.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 0, 1500, 1416] 0 0 1500 1416
# Saved cropped image
# {'x': 831, 'y': 975, 'width': 1308, 'height': 645, 'confidence': 0.6912319660186768, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\VongrasigConvertibleSectionalSofaCouchSeatLShapedSofawithRemovablePillowsLinenFabricSmallCouchMidCenturyforLivingRoomApartmentandOfficeGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 358, 'y': 387, 'width': 97, 'height': 176, 'confidence': 0.5206226110458374, 'class': 'Frame', 'class_id': 10, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\VongrasigConvertibleSectionalSofaCouchSeatLShapedSofawithRemovablePillowsLinenFabricSmallCouchMidCenturyforLivingRoomApartmentandOfficeGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [177, 653, 1485, 1297] 177 653 1485 1297
# Saved cropped image
# [310, 299, 406, 475] 310 299 406 475
# Saved cropped image
# {'x': 751, 'y': 1115, 'width': 1431, 'height': 746, 'confidence': 0.9186570644378662, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\VyfiptFutonBedCouchBrownFauxLeatherMemoryFoamSmallSplitbackConvertBackrestsArmrestsEasytoCleanCushionThickerVersionSofasxxIN.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 1240, 'y': 382, 'width': 504, 'height': 764, 'confidence': 0.6277593374252319, 'class': 'Window', 'class_id': 23, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\VyfiptFutonBedCouchBrownFauxLeatherMemoryFoamSmallSplitbackConvertBackrestsArmrestsEasytoCleanCushionThickerVersionSofasxxIN.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [36, 742, 1466, 1488] 36 742 1466 1488
# Saved cropped image
# [988, 0, 1492, 764] 988 0 1492 764
# Saved cropped image
# {'x': 724, 'y': 1042, 'width': 1362, 'height': 735, 'confidence': 0.5219439268112183, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\YESHOMYConvertibleSectionalLShapedCouchSoftSeatwithModernLinenFabricSpaceSavingSofasforLivingRoomApartmentandOfficeDarkGray.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [43, 675, 1405, 1409] 43 675 1405 1409
# Saved cropped image
# {'x': 750, 'y': 332, 'width': 1500, 'height': 664, 'confidence': 0.7064805030822754, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\YESHOMYConvertibleSectionalSofaUShapedCouchwithSoftModernCottonChenilleFabricforLivingRoomOversizedSeatswithComfortableBackrestWhite.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [0, 0, 1500, 664] 0 0 1500 664
# Saved cropped image
# {'x': 771, 'y': 827, 'width': 1240, 'height': 580, 'confidence': 0.609296441078186, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\YoumumeubConvertibleSectionalSofaCouchSeatSofawithStorageOttomanModernSofasCouchesforLivingRoomSingleApartmentandHotelDarkGrey.jpg', 'prediction_type': 'ObjectDetectionModel'}
# {'x': 1137, 'y': 1251, 'width': 688, 'height': 461, 'confidence': 0.5292959213256836, 'class': 'Table', 'class_id': 20, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\YoumumeubConvertibleSectionalSofaCouchSeatSofawithStorageOttomanModernSofasCouchesforLivingRoomSingleApartmentandHotelDarkGrey.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [151, 537, 1391, 1117] 151 537 1391 1117
# Saved cropped image
# [793, 1021, 1481, 1481] 793 1021 1481 1481
# Saved cropped image
# {'x': 706, 'y': 1290, 'width': 548, 'height': 375, 'confidence': 0.7144429683685303, 'class': 'Table', 'class_id': 20, 'image_path': 'C:\\Users\\user\\Desktop\\BigF\\team5\\Detection\\test_crawling_data\\YuuYeeModernCouchwChaiseSleeperLShapedSofaCouchReversibleChenilleSmallSectionalSofaSofawithChaiseMidModernCenturyCouchwithRemovableandWashableCushionsNavy.jpg', 'prediction_type': 'ObjectDetectionModel'}
# [432, 1103, 980, 1477] 432 1103 980 1477
# Saved cropped image

# %% [markdown]
# #### 박스 제외 지우기

# %%
# import cv2

# # 이미지 로드
# img = cv2.imread(full_path)

# # 객체 탐지 후, 바운딩 박스 좌표 예시
# boxes = [[x1, y1, x2, y2], ...]

# # 이미지의 복사본 생성
# mask = np.zeros_like(img)

# for box in boxes:
#     x1, y1, x2, y2 = box
#     # 바운딩 박스 영역을 복사본에 복사
#     mask[y1:y2, x1:x2] = img[y1:y2, x1:x2]

# # 결과 이미지 보기
# cv2.imshow("Masked Image", mask)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# {'x': 719, 'y': 289, 'width': 1438, 'height': 578, 'confidence': 0.8438215255737305, 'class': 'Sofa', 'class_id': 18, 'image_path': 'C:\\Users\\user\\Desktop\\Detector\\yolo\\test_crawlingdata\\CasaAndreaMilanoModernVelvetFabricSectionalSofaLShapeCouchwithExtraWideChaiseLounge.jpg', 'prediction_type': 'ObjectDetectionModel'}
# 719 289 2157 867
